# %%
import os
os.chdir('..')
print(os.getcwd())
# Out:
# /mnt/SamsungSSD/workspace/yoshioka/rendering

# %%
import os
os.environ['PYOPENGL_PLATFORM'] = 'egl'
import trimesh
import pyrender
import numpy as np

fuze_trimesh = trimesh.load('data/models/002_master_chef_can/textured_simple.obj')
mesh = pyrender.Mesh.from_trimesh(fuze_trimesh)
camera = pyrender.PerspectiveCamera(yfov=(np.pi / 3.0))
camera_pose = np.eye(4)

scene = pyrender.Scene()
scene.add(mesh)
scene.add(camera, pose=camera_pose)
r = pyrender.OffscreenRenderer(640, 480)
color, depth = r.render(scene)

# pyrender.Viewer(scene, use_raymond_lighting=True)

# %%
import matplotlib.pyplot as plt

plt.imshow(color)
plt.show()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-x454_g8e because the default path (/home/yshugo/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
